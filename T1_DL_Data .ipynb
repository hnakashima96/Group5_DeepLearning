# %%
#basic libraries 
import os

import IPython.display as ipd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl

# %%
tracks = pd.read_csv(r'C:\Users\hirom\Documents\GitHub\Group5_DeepLearning\fma_metadata\tracks.csv', low_memory=False, index_col=0, header=[0, 1])
genres = pd.read_csv(r'C:\Users\hirom\Documents\GitHub\Group5_DeepLearning\fma_metadata\genres.csv', low_memory=False, index_col=0)
features = pd.read_csv(r'C:\Users\hirom\Documents\GitHub\Group5_DeepLearning\fma_metadata\features.csv', low_memory=False, index_col=0, header=[0, 1, 2])
echonest = pd.read_csv(r'C:\Users\hirom\Documents\GitHub\Group5_DeepLearning\fma_metadata\echonest.csv', low_memory=False,  index_col=0, header=[0, 1, 2])

# %% [markdown]
# ## Data Imported

# %% [markdown]
# ### Undestanding the track dataset
#
# - Dataset which represents the music

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106574 entries, 2 to 155320
# Data columns (total 52 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   (album, comments)            106574 non-null  int64
#  1   (album, date_created)        103045 non-null  object
#  2   (album, date_released)       70294 non-null   object
#  3   (album, engineer)            15295 non-null   object
#  4   (album, favorites)           106574 non-null  int64
#  5   (album, id)                  106574 non-null  int64
#  6   (album, information)         83149 non-null   object
#  7   (album, listens)             106574 non-null  int64
#  8   (album, producer)            18060 non-null   object
#  9   (album, tags)                106574 non-null  object
#  10  (album, title)               105549 non-null  object
#  11  (album, tracks)              106574 non-null  int64
# ...

# %%
tracks['track'].head()
# Out:
#           bit_rate  comments   composer         date_created  \
# track_id
# 2           256000         0        NaN  2008-11-26 01:48:12
# 3           256000         0        NaN  2008-11-26 01:48:14
# 5           256000         0        NaN  2008-11-26 01:48:20
# 10          192000         0  Kurt Vile  2008-11-25 17:49:06
# 20          256000         0        NaN  2008-11-26 01:48:56
#
#                 date_recorded  duration  favorites genre_top     genres  \
# track_id
# 2         2008-11-26 00:00:00       168          2   Hip-Hop       [21]
# 3         2008-11-26 00:00:00       237          1   Hip-Hop       [21]
# 5         2008-11-26 00:00:00       206          6   Hip-Hop       [21]
# 10        2008-11-26 00:00:00       161        178       Pop       [10]
# 20        2008-01-01 00:00:00       311          0       NaN  [76, 103]
#
#                  genres_all information  interest language_code  \
# track_id
# 2                      [21]         NaN      4656            en
# ...

# %%
tracks['album'].head()
# Out:
#           comments         date_created        date_released engineer  \
# track_id
# 2                0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3                0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 5                0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 10               0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# 20               0  2008-11-26 01:45:05  2009-01-06 00:00:00      NaN
#
#           favorites  id                                information  listens  \
# track_id
# 2                 4   1                                    <p></p>     6073
# 3                 4   1                                    <p></p>     6073
# 5                 4   1                                    <p></p>     6073
# 10                4   6                                        NaN    47632
# 20                2   4  <p> "spiritual songs" from Nicky Cook</p>     2710
#
#          producer tags                 title  tracks   type
# ...

# %%
tracks['artist'].head()
# Out:
#             active_year_begin      active_year_end  \
# track_id
# 2         2006-01-01 00:00:00                  NaN
# 3         2006-01-01 00:00:00                  NaN
# 5         2006-01-01 00:00:00                  NaN
# 10                        NaN                  NaN
# 20        1990-01-01 00:00:00  2011-01-01 00:00:00
#
#                                           associated_labels  \
# track_id
# 2                                                       NaN
# 3                                                       NaN
# 5                                                       NaN
# 10        Mexican Summer, Richie Records, Woodsist, Skul...
# 20                                                      NaN
#
#                                                         bio  comments  \
# track_id
# 2         <p>A Way Of Life, A Collective of Hip-Hop from...         0
# 3         <p>A Way Of Life, A Collective of Hip-Hop from...         0
# ...

# %%
tracks['set'].head()
# Out:
#              split  subset
# track_id
# 2         training   small
# 3         training  medium
# 5         training   small
# 10        training   small
# 20        training   large

# %%
small = tracks[tracks['set', 'subset'] == 'small']
small.shape
# Out:
# (8000, 52)

# %%
small.head(3)
# Out:
#             album                                                     \
#          comments         date_created        date_released engineer
# track_id
# 2               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 5               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 10              0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
#
#                                                          ...       track  \
#          favorites id information listens producer tags  ... information
# track_id                                                 ...
# 2                4  1     <p></p>    6073      NaN   []  ...         NaN
# 5                4  1     <p></p>    6073      NaN   []  ...         NaN
# 10               4  6         NaN   47632      NaN   []  ...         NaN
#
#                                  \
#          interest language_code
# track_id
# 2            4656            en
# 5            1933            en
# 10          54881            en
#
# ...

# %% [markdown]
# ## Genres dataset

# %%
genres.head(3)
# Out:
#           #tracks  parent          title  top_level
# genre_id
# 1            8693      38    Avant-Garde         38
# 2            5271       0  International          2
# 3            1752       0          Blues          3

# %%
genres['title'].value_counts()
# Out:
# Bollywood        1
# Soundtrack       1
# Dance            1
# Radio Theater    1
# Improv           1
#                 ..
# Choral Music     1
# Klezmer          1
# Indie-Rock       1
# Surf             1
# Novelty          1
# Name: title, Length: 163, dtype: int64

# %% [markdown]
# - What is the top level feature?

# %%
genres.loc[genres['top_level'].unique()].sort_values('#tracks', ascending=False)
# Out:
#           #tracks  parent                title  top_level
# genre_id
# 38          38154       0         Experimental         38
# 15          34413       0           Electronic         15
# 12          32923       0                 Rock         12
# 1235        14938       0         Instrumental       1235
# 10          13845       0                  Pop         10
# 17          12706       0                 Folk         17
# 21           8389       0              Hip-Hop         21
# 2            5271       0        International          2
# 4            4126       0                 Jazz          4
# 5            4106       0            Classical          5
# 9            1987       0              Country          9
# 20           1876       0               Spoken         20
# 3            1752       0                Blues          3
# 14           1499       0             Soul-RnB         14
# 8             868       0  Old-Time / Historic          8
# ...

# %% [markdown]
# ## Features dataset
#
# - Represents the features extracted from the audios

# %%
features.head(3)
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# track_id
# 2             7.180653  5.230309  0.249321  1.347620  1.482478  0.531371
# 3             1.888963  0.760539  0.345297  2.295201  1.654031  0.067592
# 5             0.527563 -0.077654 -0.279610  0.685883  1.937570  0.880839
#
# feature                                             ...   tonnetz            \
# statistics                                          ...       std
# number            07        08        09        10  ...        04        05
# track_id                                            ...
# 2           1.481593  2.691455  0.866868  1.341231  ...  0.054125  0.012226
# 3           1.366848  1.054094  0.108103  0.619185  ...  0.063831  0.014212
# 5          -0.923192 -0.927232  0.666617  1.038546  ...  0.040730  0.012691
#
# ...

# %% [markdown]
# ## Echonest

# %%
echonest.head(3)
# Out:
#                echonest                                                    \
#          audio_features
#            acousticness danceability    energy instrumentalness  liveness
# track_id
# 2              0.416675     0.675894  0.634476         0.010628  0.177647
# 3              0.374408     0.528643  0.817461         0.001851  0.105880
# 5              0.043567     0.745566  0.701470         0.000697  0.373143
#
#                                                                ...  \
#                                           metadata             ...
#          speechiness    tempo   valence album_date album_name  ...
# track_id                                                       ...
# 2           0.159310  165.922  0.576661        NaN        NaN  ...
# 3           0.461818  126.957  0.269240        NaN        NaN  ...
# 5           0.124595  100.260  0.621661        NaN        NaN  ...
#
#                                                                               \
# ...

# %%
## IMPORT TRACK TEST 
import librosa
import os, shutil

original_dataset_dir = os.environ.get(r'C:\Users\hirom\Documents\GitHub\Group5_DeepLearning\genres\disco')

# %%
test = librosa.example('nutcracker')

# %%
y, sr = librosa.load(test)
tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)

# %%
print('Estimated tempo: {:.2f} beats per minute'.format(tempo))
# Out:
# Estimated tempo: 107.67 beats per minute

# %%
beat_times = librosa.frames_to_time(beat_frames, sr=sr)

# %%
beat_times
# Out:
# array([  1.18421769,   1.71827664,   2.32199546,   2.87927438,
#          3.45977324,   4.01705215,   4.59755102,   5.13160998,
#          5.7353288 ,   6.29260771,   6.84988662,   7.40716553,
#          7.9876644 ,   8.54494331,   9.12544218,   9.65950113,
#         10.21678005,  10.72761905,  11.28489796,  11.79573696,
#         12.32979592,  12.86385488,  13.42113379,  13.95519274,
#         14.4892517 ,  15.02331066,  15.55736961,  16.09142857,
#         16.62548753,  17.15954649,  17.69360544,  18.25088435,
#         18.80816327,  19.31900227,  19.87628118,  20.38712018,
#         20.92117914,  21.4552381 ,  21.98929705,  22.52335601,
#         23.05741497,  23.59147392,  24.12553288,  24.65959184,
#         25.19365079,  25.72770975,  26.26176871,  26.81904762,
#         27.35310658,  27.88716553,  28.44444444,  29.00172336,
#         29.55900227,  30.11628118,  30.67356009,  31.20761905,
#         31.78811791,  32.34539683,  32.85623583,  33.36707483,
# ...

# %%
import os 

tracks_disco = r'C:\Users\hirom\Documents\GitHub\Group5_DeepLearning\genres\disco'

# %%
ls original_dataset_dir
# Out:
#  O volume na unidade C é Windows
#  O Número de Série do Volume é 666C-A66E
#
#  Pasta de C:\Users\hirom\Documents\GitHub\Group5_DeepLearning
# Arquivo não encontrado

# %%
y,sr = librosa.load(r'C:\Users\hirom\Documents\GitHub\Group5_DeepLearning\genres\disco\disco.00000.wav')

# %%
tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)
print('Estimated tempo: {:.2f} beats per minute'.format(tempo))
# Out:
# Estimated tempo: 117.45 beats per minute

# %%
start, end = 7, 17
ipd.Audio(data=y[start*sr:end*sr], rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
